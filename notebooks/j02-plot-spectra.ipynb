# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt

# %%
from boxas.config import get_config
from boxas.plot_spectra import plot_optimized_spectra

# %%
cfg = get_config('cfg_foils.yaml')
project_root = cfg['dir']['project_root']

# %%
metrics = ['l2_norm_dist']#, 'cosine_sim', 'pearson_corr', 'spearman_corr']

for material in cfg['exp_data'].keys():
    if material not in ['Ni_aps']:
        continue

    e_range = (cfg['exp_data'][material]['energy']['min']-15, cfg['exp_data'][material]['energy']['max']+20)  # Wider plotting range
    
    fig, spectra, names = plot_optimized_spectra(cfg, 'feff', material, metrics, e_range)
    # plt.savefig(f'{output_dir}/fig-feff-opt-{material}.eps', format='eps', bbox_inches='tight')
    
    plt.show()
# Out:
# Ni_aps :  8133.0 9233
